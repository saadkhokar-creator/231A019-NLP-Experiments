# %% [markdown]
# <a href="https://colab.research.google.com/github/saadkhokar-creator/231A019-NLP-Experiments/blob/main/nlp6ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Name:Saad Khokar, UIN:231A019")
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import UnigramTagger, BigramTagger,pos_tag
from nltk.corpus import treebank
from nltk import pos_tag_sents
# Out:
# Name:Saad Khokar, UIN:231A019

# %%
print("Name:Saad Khokar, UIN:231A019")

nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
nltk.download('treebank')
# Out:
# Name:Saad Khokar, UIN:231A019
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Unzipping corpora/treebank.zip.
# True

# %%
print("Name:Saad Khokar, UIN:231A019")
import nltk
from nltk.tokenize import word_tokenize


sample_text = "The quick brown fox jumps over the lazy dog. The lazy dog barks."


nltk.download('punkt_tab')


tokens = word_tokenize(sample_text)
# Out:
# Name:Saad Khokar, UIN:231A019
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
print("Name:Saad Khokar, UIN:231A019")

nltk.download('averaged_perceptron_tagger_eng')
rule_based_tags = pos_tag(tokens)
# Out:
# Name:Saad Khokar, UIN:231A019
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.

# %%
print("Name:Saad Khokar, UIN:231A019")
print(rule_based_tags)
# Out:
# Name:Saad Khokar, UIN:231A019
# [('The', 'DT'), ('quick', 'JJ'), ('brown', 'NN'), ('fox', 'NN'), ('jumps', 'VBZ'), ('over', 'IN'), ('the', 'DT'), ('lazy', 'JJ'), ('dog', 'NN'), ('.', '.'), ('The', 'DT'), ('lazy', 'JJ'), ('dog', 'NN'), ('barks', 'NNS'), ('.', '.')]

# %%
print("Name:Saad Khokar, UIN:231A019")
nltk.download('tagsets_json')
nltk.help.upenn_tagset("NNS")
# Out:
# Name:Saad Khokar, UIN:231A019
# NNS: noun, common, plural
#     undergraduates scotches bric-a-brac products bodyguards facets coasts
#     divestitures storehouses designs clubs fragrances averages
#     subjectivists apprehensions muses factory-jobs ...
# [nltk_data] Downloading package tagsets_json to /root/nltk_data...
# [nltk_data]   Unzipping help/tagsets_json.zip.

# %%
print("Name:Saad Khokar, UIN:231A019")
nltk.help.upenn_tagset("DT")
# Out:
# Name:Saad Khokar, UIN:231A019
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those

# %%
print("Name:Saad Khokar, UIN:231A019")
nltk.help.upenn_tagset("VBZ")
# Out:
# Name:Saad Khokar, UIN:231A019
# VBZ: verb, present tense, 3rd person singular
#     bases reconstructs marks mixes displeases seals carps weaves snatches
#     slumps stretches authorizes smolders pictures emerges stockpiles
#     seduces fizzes uses bolsters slaps speaks pleads ...

# %%
print("Name:Saad Khokar, UIN:231A019")
nltk.help.upenn_tagset("JJ")
# Out:
# Name:Saad Khokar, UIN:231A019
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...

# %%
print("Name:Saad Khokar, UIN:231A019")

train_sents =  treebank.tagged_sents()

unigram_tagger =  UnigramTagger (train_sents)
unigram_tags = unigram_tagger.tag(tokens)

bigram_tagger =  BigramTagger(train_sents, backoff=unigram_tagger)
bigram_tags = bigram_tagger.tag(tokens)
# Out:
# Name:Saad Khokar, UIN:231A019

# %%
print("Name:Saad Khokar, UIN:231A019")
bigram_tags
# Out:
# Name:Saad Khokar, UIN:231A019
# [('The', 'DT'),
#  ('quick', 'JJ'),
#  ('brown', None),
#  ('fox', None),
#  ('jumps', 'NNS'),
#  ('over', 'IN'),
#  ('the', 'DT'),
#  ('lazy', None),
#  ('dog', None),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('lazy', None),
#  ('dog', None),
#  ('barks', None),
#  ('.', '.')]

# %%
print("Name:Saad Khokar, UIN:231A019")
unigram_tags
# Out:
# Name:Saad Khokar, UIN:231A019
# [('The', 'DT'),
#  ('quick', 'JJ'),
#  ('brown', None),
#  ('fox', None),
#  ('jumps', 'NNS'),
#  ('over', 'IN'),
#  ('the', 'DT'),
#  ('lazy', None),
#  ('dog', None),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('lazy', None),
#  ('dog', None),
#  ('barks', None),
#  ('.', '.')]

# %%
print("Name:Saad Khokar, UIN:231A019")
rule_based_tags
# Out:
# Name:Saad Khokar, UIN:231A019
# [('The', 'DT'),
#  ('quick', 'JJ'),
#  ('brown', 'NN'),
#  ('fox', 'NN'),
#  ('jumps', 'VBZ'),
#  ('over', 'IN'),
#  ('the', 'DT'),
#  ('lazy', 'JJ'),
#  ('dog', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('lazy', 'JJ'),
#  ('dog', 'NN'),
#  ('barks', 'NNS'),
#  ('.', '.')]

# %%
print("Name:Saad Khokar, UIN:231A019")
train_sents[:10]
# Out:
# Name:Saad Khokar, UIN:231A019
# [[('Pierre', 'NNP'),
#   ('Vinken', 'NNP'),
#   (',', ','),
#   ('61', 'CD'),
#   ('years', 'NNS'),
#   ('old', 'JJ'),
#   (',', ','),
#   ('will', 'MD'),
#   ('join', 'VB'),
#   ('the', 'DT'),
#   ('board', 'NN'),
#   ('as', 'IN'),
#   ('a', 'DT'),
#   ('nonexecutive', 'JJ'),
#   ('director', 'NN'),
#   ('Nov.', 'NNP'),
#   ('29', 'CD'),
#   ('.', '.')],
#  [('Mr.', 'NNP'),
#   ('Vinken', 'NNP'),
#   ('is', 'VBZ'),
#   ('chairman', 'NN'),
#   ('of', 'IN'),
#   ('Elsevier', 'NNP'),
#   ('N.V.', 'NNP'),
#   (',', ','),
#   ('the', 'DT'),
#   ('Dutch', 'NNP'),
#   ('publishing', 'VBG'),
#   ('group', 'NN'),
#   ('.', '.')],
#  [('Rudolph', 'NNP'),
#   ('Agnew', 'NNP'),
#   (',', ','),
#   ('55', 'CD'),
#   ('years', 'NNS'),
#   ('old', 'JJ'),
#   ('and', 'CC'),
#   ('former', 'JJ'),
#   ('chairman', 'NN'),
#   ('of', 'IN'),
#   ('Consolidated', 'NNP'),
#   ('Gold', 'NNP'),
#   ('Fields', 'NNP'),
#   ('PLC', 'NNP'),
#   (',', ','),
#   ('was', 'VBD'),
# ...

# %%
print("Name:Saad Khokar, UIN:231A019")
len(train_sents)
# Out:
# Name:Saad Khokar, UIN:231A019
# 3914

# %%
print("Name:Saad Khokar, UIN:231A019")
print("Original Sentence:", sample_text)
print("\nRule-Based POS Tagging (Statistical):")
print(rule_based_tags)
print("\nUnigram POS Tagging:")
print(unigram_tags)
print("\nBigram POS Tagging:")
print(bigram_tags)
# Out:
# Name:Saad Khokar, UIN:231A019
# Original Sentence: The quick brown fox jumps over the lazy dog. The lazy dog barks.
#
# Rule-Based POS Tagging (Statistical):
# [('The', 'DT'), ('quick', 'JJ'), ('brown', 'NN'), ('fox', 'NN'), ('jumps', 'VBZ'), ('over', 'IN'), ('the', 'DT'), ('lazy', 'JJ'), ('dog', 'NN'), ('.', '.'), ('The', 'DT'), ('lazy', 'JJ'), ('dog', 'NN'), ('barks', 'NNS'), ('.', '.')]
#
# Unigram POS Tagging:
# [('The', 'DT'), ('quick', 'JJ'), ('brown', None), ('fox', None), ('jumps', 'NNS'), ('over', 'IN'), ('the', 'DT'), ('lazy', None), ('dog', None), ('.', '.'), ('The', 'DT'), ('lazy', None), ('dog', None), ('barks', None), ('.', '.')]
#
# Bigram POS Tagging:
# [('The', 'DT'), ('quick', 'JJ'), ('brown', None), ('fox', None), ('jumps', 'NNS'), ('over', 'IN'), ('the', 'DT'), ('lazy', None), ('dog', None), ('.', '.'), ('The', 'DT'), ('lazy', None), ('dog', None), ('barks', None), ('.', '.')]

# %%
print("Name:Saad Khokar, UIN:231A019")
test_sents = treebank.tagged_sents()[3000:]
unigram_acc = unigram_tagger.evaluate(test_sents)
bigram_acc = bigram_tagger.evaluate(test_sents)
print(f"\nUnigram Tagger Accuracy: {unigram_acc * 100:.2f}%")
print(f"Bigram Tagger Accuracy: {bigram_acc * 100:.2f}%")
# Out:
# Name:Saad Khokar, UIN:231A019
# /tmp/ipykernel_2177/2492914510.py:3: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   unigram_acc = unigram_tagger.evaluate(test_sents)
# /tmp/ipykernel_2177/2492914510.py:4: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   bigram_acc = bigram_tagger.evaluate(test_sents)
# Unigram Tagger Accuracy: 96.32%
# Bigram Tagger Accuracy: 98.63%
